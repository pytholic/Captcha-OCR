# %% [markdown]
# # Introduction

# %% [markdown]
# This example demonstrates a simple **OCR** model built with the Functional API. Apart from combining CNN and RNN, it also illustrates how you can instantiate a new layer and use it as an "Endpoint layer" for implementing CTC loss.

# %% [markdown]
# # Setup

# %%
import os, glob
import numpy as np
import matplotlib.pyplot as plt

from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import warnings
warnings.filterwarnings('ignore')
#tf.compat.v1.reset_default_graph()
# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession

# config = ConfigProto()
# config.gpu_options.allow_growth = True
# session = InteractiveSession(config=config)

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_8720/337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2022-06-12 23:32:33.796528: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-12 23:32:33.862649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:33.888855: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:33.889192: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:34.241620: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:34.241805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:34.241895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:34.241983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 5881 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# True

# %% [markdown]
# # Load the data

# %%
# # Downlaod and unzip the data
# !curl -LO https://github.com/AakashKumarNain/CaptchaCracker/raw/master/captcha_images_v2.zip
# !unzip -qq captcha_images_v2.zip

# %% [markdown]
# The dataset contains `1040` captcha files as `png` images. The label for each sample is a string, the name of the file (minus the file extension). We will map each character in the string to an integer for training the model. Similary, we will need to map the predictions of the model back to strings. For this purpose we will maintain two dictionaries, mapping characters to integers, and integers to characters, respectively.

# %%
# Path to data directory
data_dir = os.path.abspath('./captcha_images_v2')

# Get list of all images
images = sorted(glob.glob(data_dir + '/*.png'))
labels = [img.split('/')[-1].split('.')[0] for img in images]
characters = set(char for label in labels for char in label)

print("Number of images found: ", len(images))
print("Number of labels found: ", len(labels))
print("Number of unique characters: ", len(characters))
print("Characters present: ", characters)
# Out:
# Number of images found:  1040
# Number of labels found:  1040
# Number of unique characters:  19
# Characters present:  {'g', 'c', 'x', 'f', 'b', 'y', '4', 'p', 'n', '3', 'w', '7', 'e', '8', 'm', '2', '6', 'd', '5'}

# %% [markdown]
# # Hyperparameters

# %%
batch_size = 16
img_width = 200
img_height = 50
downsample_factor = 4

# Max length of any captha in the dataset
# for constant length of the labels
max_length = max([len(label) for label in labels])

# %% [markdown]
# # Preprocessing

# %%
# Mapping characters to integers
char_to_num = layers.experimental.preprocessing.StringLookup(
    vocabulary=list(characters), mask_token=None
)

# Mapping integers back to original characters
num_to_char = layers.experimental.preprocessing.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True
)
# Out:
# 2022-06-12 23:32:42.794791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.795295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.795701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.796294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.796490: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.796664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.796881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.797321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-12 23:32:42.797755: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5881 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images)
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
    return x_train, x_valid, y_train, y_valid

# Splitting data into training and validation sets
x_train, x_valid, y_train, y_valid = split_data(np.array(images), np.array(labels))

# %%
def encode_single_sample(img_path, label):
    # 1. Read image
    img = tf.io.read_file(img_path)
    # 2. Decode and convert to grayscale
    img = tf.io.decode_png(img, channels=1)
    # 3. Convert to float32 in [0, 1] range
    img = tf.image.convert_image_dtype(img, tf.float32)
    # 4. Resize to the desired size
    img = tf.image.resize(img, [img_height, img_width])
    # 5. Transpose the image because we want the time
    # dimension to correspond to the width of the image.
    img = tf.transpose(img, perm=[1, 0, 2])
    # 6. Map the characters in label to numbers
    label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
    # 7. Return a dict as our model is expecting two inputs
    #return img, label
    return {"image": img, "label": label}

# %% [markdown]
# # Create dataset objects

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = (
    train_dataset.map(
        encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE
    )
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

validation_dataset = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))
validation_dataset = (
    validation_dataset.map(
        encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE
    )
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %% [markdown]
# # Visualize the data

# %%
_, ax = plt.subplots(4, 4, figsize=(10, 5))
for batch in train_dataset.take(1):
    images = batch["image"]
    labels = batch["label"]
    for i in range(16):
        img = (images[i] * 255).numpy().astype("uint8")
        label = tf.strings.reduce_join(num_to_char(labels[i])).numpy().decode("utf-8")
        ax[i // 4, i % 4].imshow(img[:, :, 0].T, cmap="gray")
        ax[i // 4, i % 4].set_title(label)
        ax[i // 4, i % 4].axis("off")
plt.show()
# Out:
# 2022-06-12 23:32:47.150862: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# # Model

# %%
class CTCLayer(layers.Layer):
    """
    Implement custom loss function as a layer. It becomes part of the
    model.
    """
    def __init__(self, name=None):
        super().__init__(name=name)
        #self.loss_fn = keras.backend.categorical_crossentropy
        self.loss_fn = keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred):
        # Compute the training-time loss value and add it
        # to the layer using `self.add_loss()`.
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
        input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
        label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

        input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)

        # At test time, just return the computed predictions
        return y_pred

# %%
def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_width, img_height, 1), name="image", dtype="float32"
    )
    labels = layers.Input(name="label", shape=(None,), dtype="float32")

    # First conv block
    x = layers.Conv2D(
        32,
        (5, 5),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = layers.MaxPooling2D((2, 2), name="pool1")(x)

    # Second conv block
    x = layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = layers.MaxPooling2D((2, 2), name="pool2")(x)
    
    # Third conv block
    x = layers.Conv2D(
        128,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv3",
    )(x)
    #x = layers.MaxPooling2D((2, 2), name="pool3")(x)

    # We have used two max pool with pool size and strides 2.
    # Hence, downsampled feature maps are 4x smaller. The number of
    # filters in the last layer is 64. Reshape accordingly before
    # passing the output to the RNN part of the model
    new_shape = ((img_width // 4), (img_height // 4) * 128)
    x = layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = layers.Dense(64, activation="relu", name="dense1")(x)
    x = layers.Dropout(0.2)(x)

    # RNNs
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.25))(x)
    x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25))(x)

    # Output layer
    x = layers.Dense(
        len(char_to_num.get_vocabulary()) + 1, activation="softmax", name="dense2"
    )(x)

    # Add CTC layer for calculating CTC loss at each step
    output = CTCLayer(name="ctc_loss")(labels, x)

    # Define the model
    model = keras.models.Model(
        inputs=[input_img, labels], outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(optimizer=opt)
    return model


# Get the model
model = build_model()
model.summary()
# Out:
# Model: "ocr_model_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 200, 50, 1)] 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 200, 50, 32)  832         image[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 100, 25, 32)  0           Conv1[0][0]
# __________________________________________________________________________________________________
# Conv2 (Conv2D)                  (None, 100, 25, 64)  18496       pool1[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 50, 12, 64)   0           Conv2[0][0]
# __________________________________________________________________________________________________
# Conv3 (Conv2D)                  (None, 50, 12, 128)  73856       pool2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 50, 1536)     0           Conv3[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 50, 64)       98368       reshape[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 50, 64)       0           dense1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 50, 256)      197632      dropout[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 50, 128)      164352      bidirectional[0][0]
# __________________________________________________________________________________________________
# label (InputLayer)              [(None, None)]       0
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 50, 21)       2709        bidirectional_1[0][0]
# __________________________________________________________________________________________________
# ctc_loss (CTCLayer)             (None, 50, 21)       0           label[0][0]
#                                                                  dense2[0][0]
# ==================================================================================================
# Total params: 556,245
# Trainable params: 556,245
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 100
early_stopping_patience = 30
# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 2022-06-12 23:32:57.326668: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2022-06-12 23:32:57.913393: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-12 23:32:57.914189: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-12 23:32:57.914252: W tensorflow/stream_executor/gpu/asm_compiler.cc:77] Couldn't get ptxas version string: Internal: Couldn't invoke ptxas --version
# 2022-06-12 23:32:57.915089: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-06-12 23:32:57.915205: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-06-12 23:32:58.512210: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 59/59 [==============================] - 7s 34ms/step - loss: 19.9239 - val_loss: 16.2824
# Epoch 2/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.3847 - val_loss: 16.2602
# Epoch 3/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.3711 - val_loss: 16.2737
# Epoch 4/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.3598 - val_loss: 16.2760
# Epoch 5/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.3568 - val_loss: 16.2800
# Epoch 6/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.3480 - val_loss: 16.2848
# Epoch 7/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.3358 - val_loss: 16.2890
# Epoch 8/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.3201 - val_loss: 16.2903
# Epoch 9/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.2976 - val_loss: 16.2860
# Epoch 10/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.2598 - val_loss: 16.2734
# Epoch 11/100
# 59/59 [==============================] - 1s 20ms/step - loss: 16.2106 - val_loss: 16.3471
# Epoch 12/100
# 59/59 [==============================] - 1s 21ms/step - loss: 16.1178 - val_loss: 16.2874
# Epoch 13/100
# 59/59 [==============================] - 1s 20ms/step - loss: 15.9768 - val_loss: 16.1072
# Epoch 14/100
# 59/59 [==============================] - 1s 20ms/step - loss: 15.8187 - val_loss: 16.0922
# Epoch 15/100
# 59/59 [==============================] - 1s 20ms/step - loss: 15.6939 - val_loss: 15.9762
# 59/59 [==============================] - 1s 21ms/step - loss: 6.3610 - val_loss: 3.4858
# Epoch 48/100
# 59/59 [==============================] - 1s 21ms/step - loss: 3.0291 - val_loss: 1.6619
# Epoch 49/100
# 59/59 [==============================] - 1s 20ms/step - loss: 1.7678 - val_loss: 1.0757
# Epoch 50/100
# 59/59 [==============================] - 1s 20ms/step - loss: 1.0993 - val_loss: 0.7232
# Epoch 51/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.8704 - val_loss: 0.5772
# Epoch 52/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.6666 - val_loss: 0.4505
# Epoch 53/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.5318 - val_loss: 0.3628
# Epoch 54/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.4051 - val_loss: 0.2683
# Epoch 55/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.4408 - val_loss: 0.3712
# Epoch 56/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.3011 - val_loss: 0.2017
# Epoch 57/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.2231 - val_loss: 0.2854
# Epoch 58/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.2486 - val_loss: 0.2856
# Epoch 59/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.1842 - val_loss: 0.2654
# Epoch 60/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.1555 - val_loss: 0.1471
# Epoch 61/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.1593 - val_loss: 0.1857
# Epoch 62/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.1447 - val_loss: 0.1638
# Epoch 63/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.1014 - val_loss: 0.2143
# Epoch 64/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0928 - val_loss: 0.1845
# Epoch 65/100
# 59/59 [==============================] - 1s 21ms/step - loss: 0.0505 - val_loss: 0.1351
# Epoch 66/100
# 59/59 [==============================] - 1s 22ms/step - loss: 0.0619 - val_loss: 0.1825
# Epoch 67/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0449 - val_loss: 0.1484
# Epoch 68/100
# 59/59 [==============================] - 1s 21ms/step - loss: 0.0751 - val_loss: 0.1240
# Epoch 69/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0485 - val_loss: 0.1491
# Epoch 70/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.1347 - val_loss: 0.0994
# Epoch 71/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0812 - val_loss: 0.1264
# Epoch 72/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0689 - val_loss: 0.1747
# Epoch 73/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0794 - val_loss: 0.2264
# Epoch 74/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0813 - val_loss: 0.1633
# Epoch 75/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0312 - val_loss: 0.1296
# Epoch 76/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0260 - val_loss: 0.1319
# Epoch 77/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0317 - val_loss: 0.1301
# Epoch 78/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0266 - val_loss: 0.1277
# Epoch 79/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0382 - val_loss: 0.1372
# Epoch 80/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0484 - val_loss: 0.1163
# Epoch 81/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0450 - val_loss: 0.1203
# Epoch 82/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0308 - val_loss: 0.1351
# Epoch 83/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0318 - val_loss: 0.1013
# Epoch 84/100
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0263 - val_loss: 0.1125
# Epoch 85/100
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0205 - val_loss: 0.1006
# Epoch 86/100
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0874 - val_loss: 0.1109
# Epoch 87/100
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0742 - val_loss: 0.1217
# Epoch 88/100
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1065 - val_loss: 0.1237
# Epoch 89/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0637 - val_loss: 0.1356
# Epoch 90/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0333 - val_loss: 0.1387
# Epoch 91/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0401 - val_loss: 0.1163
# Epoch 92/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0335 - val_loss: 0.1074
# Epoch 93/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0198 - val_loss: 0.1073
# Epoch 94/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0182 - val_loss: 0.1918
# Epoch 95/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0344 - val_loss: 0.1011
# Epoch 96/100
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0210 - val_loss: 0.1239
# Epoch 97/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0353 - val_loss: 0.1489
# Epoch 98/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0248 - val_loss: 0.0876
# Epoch 99/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0164 - val_loss: 0.1065
# Epoch 100/100
# 59/59 [==============================] - 1s 20ms/step - loss: 0.0394 - val_loss: 0.0534

# %% [markdown]
# # Prediction

# %%
# Get the prediction model by extracting layers till the output layer
prediction_model = keras.models.Model(
    model.get_layer(name="image").input, model.get_layer(name="dense2").output
)
prediction_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image (InputLayer)           [(None, 200, 50, 1)]      0
# _________________________________________________________________
# Conv1 (Conv2D)               (None, 200, 50, 32)       832
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 100, 25, 32)       0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 100, 25, 64)       18496
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 50, 12, 64)        0
# _________________________________________________________________
# Conv3 (Conv2D)               (None, 50, 12, 128)       73856
# _________________________________________________________________
# reshape (Reshape)            (None, 50, 1536)          0
# _________________________________________________________________
# dense1 (Dense)               (None, 50, 64)            98368
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 64)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 50, 256)           197632
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 50, 128)           164352
# _________________________________________________________________
# dense2 (Dense)               (None, 50, 21)            2709
# =================================================================
# Total params: 556,245
# Trainable params: 556,245
# Non-trainable params: 0
# _________________________________________________________________

# %%
# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_length
    ]
    # Iterate over the results and get back the text
    output_text = []
    for res in results:
        res = tf.strings.reduce_join(num_to_char(res)).numpy().decode("utf-8")
        output_text.append(res)
    return output_text

# %%
#  Let's check results on some validation samples
for batch in validation_dataset.take(1):
    batch_images = batch["image"]
    batch_labels = batch["label"]

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)

    orig_texts = []
    for label in batch_labels:
        label = tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
        orig_texts.append(label)

    _, ax = plt.subplots(4, 4, figsize=(15, 5))
    for i in range(len(pred_texts)):
        img = (batch_images[i, :, :, 0] * 255).numpy().astype(np.uint8)
        img = img.T
        title = f"Prediction: {pred_texts[i]}"
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title)
        ax[i // 4, i % 4].axis("off")
plt.show()
